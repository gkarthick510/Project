# %% [markdown]
# <a href="https://colab.research.google.com/github/gkarthick510/Project/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The dataset contains key factors that could influence Residential home prices in the last 20 years in the United States. This factor falls into two categories
# i.e. Supply & Demand
#
# The S&P Case-Shiller Housing Price Index(HPI) is taken as the y variable, or dependent variable, as an indicator of change in prices.

# %% [markdown]
# .**Supply_dataset(Monthly_data)**
#
# Building Permits(Permit Number)-Number of building permits allotted
#
# Construction Spending (Million $)-
# The amount spent (in millions of USD) is a measure of the activity in the construction industry.
#
# Housing Starts(New Housing Project)-This is a measure of the number of units of new housing projects started in a given period.
#
# Homes Sold(units)-House for sale is a basic measure of supply

# %% [markdown]
# **Supply_dataset(Monthly_data)**
#
#   Mortgage Rates(%)
#
#   USA GDP(Billions$ )-Quarterly Real GDP (adjusted for inflation)
#
#   Unemployment(%)
#
#   Delinquency Rate(%) on Mortgages(Foreclosure on the mortgage)-an indicator of the number of foreclosures in real estate.

# %% [markdown]
# import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import data , demand and supply

# %%
demand=pd.read_csv('/content/demand_data.csv')
demand.head()
# Out:
#          DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI
# 0  2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1  2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2  2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3  2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4  2001-01-01       4.23      7.01  13219.251          2.34  110.48

# %%
demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          84 non-null     object
#  1   UNEM_RATE     84 non-null     float64
#  2   MORTGAGE      84 non-null     float64
#  3   GDPC1         84 non-null     float64
#  4   FORECLOSURES  84 non-null     float64
#  5   HPI           84 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# date need to be in datetime format

# %%
demand['DATE']=pd.to_datetime(demand['DATE'])

# %%
supply=pd.read_csv('/content/supply_data.csv')
supply.head()
# Out:
#    Unnamed: 0      Period  Permit_Number  construction  Homes_Sold  \
# 0           1  01-01-2000           1727        353065         873
# 1           2  01-02-2000           1692        351933         856
# 2           3  01-03-2000           1651        353452         900
# 3           4  01-04-2000           1597        356188         841
# 4           5  01-05-2000           1543        349907         857
#
#    Housing_Starts
# 0            1636
# 1            1737
# 2            1604
# 3            1626
# 4            1575

# %%
supply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      250 non-null    int64
#  1   Period          250 non-null    object
#  2   Permit_Number   250 non-null    int64
#  3   construction    250 non-null    int64
#  4   Homes_Sold      250 non-null    int64
#  5   Housing_Starts  250 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 11.8+ KB

# %%
supply['Period']=pd.to_datetime(supply["Period"], format="%d-%m-%Y").dt.strftime('%Y-%m-%d')

# %%
supply.rename(columns={'Period':'DATE'},inplace=True)

# %%
supply['DATE']=pd.to_datetime(supply['DATE'])

# %%
data=pd.merge(demand,supply)
data.to_csv('data.csv', index=False)

# %%
data.head()
# Out:
#         DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  \
# 0 2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1 2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2 2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3 2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4 2001-01-01       4.23      7.01  13219.251          2.34  110.48
#
#    Unnamed: 0  Permit_Number  construction  Homes_Sold  Housing_Starts
# 0           1           1727        353065         873            1636
# 1           4           1597        356188         841            1626
# 2           7           1542        337374         887            1463
# 3          10           1577        344095         933            1549
# 4          13           1699        348279         936            1600

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            84 non-null     datetime64[ns]
#  1   UNEM_RATE       84 non-null     float64
#  2   MORTGAGE        84 non-null     float64
#  3   GDPC1           84 non-null     float64
#  4   FORECLOSURES    84 non-null     float64
#  5   HPI             84 non-null     float64
#  6   Unnamed: 0      84 non-null     int64
#  7   Permit_Number   84 non-null     int64
#  8   construction    84 non-null     int64
#  9   Homes_Sold      84 non-null     int64
#  10  Housing_Starts  84 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 7.9 KB

# %%
data.isnull().any().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#data with no null and duplicated values

# %%
data['Day']=data['DATE'].dt.day
data['month']=data['DATE'].dt.month
data['year']=data['DATE'].dt.year

# %%
data.head()
# Out:
#         DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  \
# 0 2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1 2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2 2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3 2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4 2001-01-01       4.23      7.01  13219.251          2.34  110.48
#
#    Unnamed: 0  Permit_Number  construction  Homes_Sold  Housing_Starts  Day  \
# 0           1           1727        353065         873            1636    1
# 1           4           1597        356188         841            1626    1
# 2           7           1542        337374         887            1463    1
# 3          10           1577        344095         933            1549    1
# 4          13           1699        348279         936            1600    1
#
#    month  year
# 0      1  2000
# 1      4  2000
# 2      7  2000
# 3     10  2000
# 4      1  2001

# %%
#drop unwanted columns

# %%
data=data.drop('DATE', axis=1)
data=data.drop('Day', axis=1)
data=data.drop('Unnamed: 0', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UNEM_RATE       84 non-null     float64
#  1   MORTGAGE        84 non-null     float64
#  2   GDPC1           84 non-null     float64
#  3   FORECLOSURES    84 non-null     float64
#  4   HPI             84 non-null     float64
#  5   Permit_Number   84 non-null     int64
#  6   construction    84 non-null     int64
#  7   Homes_Sold      84 non-null     int64
#  8   Housing_Starts  84 non-null     int64
#  9   month           84 non-null     int64
#  10  year            84 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        UNEM_RATE   MORTGAGE         GDPC1  FORECLOSURES         HPI  \
# count  84.000000  84.000000     84.000000     84.000000   84.000000
# mean    5.986667   5.092381  15968.048810      4.745119  161.669405
# std     1.976243   1.324841   1762.701831      3.290622   30.778158
# min     3.600000   2.760000  12935.252000      1.410000  101.340000
# 25%     4.552500   3.942500  14821.741750      2.097500  140.495000
# 50%     5.430000   4.885000  15768.528500      3.160000  162.240000
# 75%     7.005000   6.135000  17394.926250      7.517500  182.945000
# max    13.070000   8.320000  19202.310000     11.540000  232.550000
#
#        Permit_Number   construction  Homes_Sold  Housing_Starts      month  \
# count      84.000000      84.000000    84.00000       84.000000  84.000000
# mean     1317.440476  429697.797619   697.72619     1274.440476   5.500000
# std       474.664786  123184.105531   300.88129      464.290425   3.374247
# ...

# %%
#Checking categorical variables
categorical_features=[feature for feature in data.columns if data[feature].dtypes=='O']
print('number of categorical variables:',len(categorical_features))
# Out:
# number of categorical variables: 0

# %%
#Checking Numerical variables  : float
numerical_continuous_feature=[feature for feature in data.columns if  data[feature].dtype=='float']
data[numerical_continuous_feature].head()
# Out:
#    UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI
# 0       4.03      8.26  12935.252          1.95  101.34
# 1       3.93      8.32  13170.749          1.97  103.67
# 2       4.00      8.02  13183.890          2.09  105.79
# 3       3.90      7.62  13262.250          2.23  108.27
# 4       4.23      7.01  13219.251          2.34  110.48

# %%
for feature in numerical_continuous_feature:
  data[feature]=np.log(data[feature])

# %%
data['HPI']=np.log(data['HPI'])
data['HPI'].hist()
# Out:
# <Axes: >

# %%
#
for feature in numerical_continuous_feature:
  sns.displot(data=data,x=feature,kind='ecdf')

# %%
for feature in numerical_continuous_feature:
  plt.figure(figsize=(7,5))
  sns.distplot(data[feature],kde=True)

# %%
for feature in numerical_continuous_feature:
  plt.figure(figsize=(7,5))
  plt.scatter(x=feature,y="HPI",data=data)
  plt.xlabel(feature)
  plt.ylabel("HPI")
  plt.title(feature)

# %%
data.columns
# Out:
# Index(['UNEM_RATE', 'MORTGAGE', 'GDPC1', 'FORECLOSURES', 'HPI',
#        'Permit_Number', 'construction', 'Homes_Sold', 'Housing_Starts',
#        'month', 'year'],
#       dtype='object')

# %%
#GDp vs hpi
sns.lineplot(x='HPI',y='GDPC1',data=data)
# Out:
# <Axes: xlabel='HPI', ylabel='GDPC1'>

# %%
#looking into outliers ; no outliers
for feature in numerical_continuous_feature:
  if 0 in data[feature].unique():
    pass
  else:
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %%
#Checking Numerical variables  : int
numerical_continuous_feature=[feature for feature in data.columns if  data[feature].dtype=='int']
data[numerical_continuous_feature].head()
# Out:
#    Permit_Number  construction  Homes_Sold  Housing_Starts  month  year
# 0           1727        353065         873            1636      1  2000
# 1           1597        356188         841            1626      4  2000
# 2           1542        337374         887            1463      7  2000
# 3           1577        344095         933            1549     10  2000
# 4           1699        348279         936            1600      1  2001

# %%
for feature in numerical_continuous_feature:
  sns.displot(data=data,x=feature,kind='ecdf')

# %%
# density of column
for feature in numerical_continuous_feature:
  plt.figure(figsize=(7,5))
  sns.distplot(data[feature],kde=True)

# %%
# shows relationship between pi and other columns
for feature in numerical_continuous_feature:
  plt.figure(figsize=(7,5))
  plt.scatter(x=feature,y="HPI",data=data)
  plt.xlabel(feature)
  plt.ylabel("HPI")
  plt.title(feature)

# %%
# looking ouliers ; no outliers found
for feature in numerical_continuous_feature:

  if 0 in data[feature].unique():
    pass
  else:
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %%
data.corr()
# Out:
#                 UNEM_RATE  MORTGAGE     GDPC1  FORECLOSURES       HPI  \
# UNEM_RATE        1.000000 -0.290828 -0.095880      0.665166 -0.198271
# MORTGAGE        -0.290828  1.000000 -0.836940     -0.523769 -0.598800
# GDPC1           -0.095880 -0.836940  1.000000      0.325910  0.857165
# FORECLOSURES     0.665166 -0.523769  0.325910      1.000000 -0.039763
# HPI             -0.198271 -0.598800  0.857165     -0.039763  1.000000
# Permit_Number   -0.601289  0.474214 -0.360454     -0.938878 -0.016048
# construction    -0.628830 -0.012167  0.301499     -0.751620  0.649397
# Homes_Sold      -0.470642  0.541084 -0.462034     -0.923759 -0.070062
# Housing_Starts  -0.592732  0.485789 -0.377528     -0.931095 -0.036430
# month            0.017050 -0.056169  0.053061      0.003984  0.059316
# year             0.030478 -0.896513  0.979178      0.408006  0.785858
#
#                 Permit_Number  construction  Homes_Sold  Housing_Starts  \
# ...

# %%
#Heatmap is one of the values showing charts or graphical representations in which various shades are used to represent the data.
#Darker values represent higher values and lighter represents lower values

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
#Pairplot is a representation which plots pairwise relationship in the data.

# %%
sns.pairplot(data=data)

# %% [markdown]
# Machine learning

# %%
'''Preparing the data

The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).'''

# %%
x=data.drop(['HPI'],axis=1)

# %%
y=data['HPI']

# %%
from sklearn.model_selection import train_test_split

# %%
#Now that we have our attributes and labels, the next step is to split this data into training and test sets.
# We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=1)

# %%
x_train.head(2)
# Out:
#     UNEM_RATE  MORTGAGE     GDPC1  FORECLOSURES  Permit_Number  construction  \
# 69   1.481605  1.381282  9.797949      1.302913           1255        534992
# 52   2.045109  1.252763  9.707563      2.276241            940        303792
#
#     Homes_Sold  Housing_Starts  month  year
# 69         589            1150      4  2017
# 52         446             888      1  2013

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (58, 10)
# (26, 10)
# (58,)
# (26,)

# %%
'''Training the Algorithm

We have split our data into training and testing sets, and now is finally the time to train our algorithm.'''

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error , mean_squared_error ,r2_score

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
#data prediction
y_pred
# Out:
# array([1.57037723, 1.64842208, 1.6302292 , 1.62340981, 1.66212309,
#        1.67284024, 1.61534541, 1.60747272, 1.60014651, 1.62524394,
#        1.67447066, 1.65531473, 1.63355738, 1.64511206, 1.6123989 ,
#        1.64405871, 1.6420809 , 1.60534695, 1.65013089, 1.60133225,
#        1.60313281, 1.54231198, 1.63936838, 1.61294571, 1.60146225,
#        1.59497033])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head()
# Out:
#       Actual  Predicted
# 10  1.572548   1.570377
# 67  1.652296   1.648422
# 59  1.633172   1.630229
# 33  1.632376   1.623410
# 83  1.695451   1.662123

# %%
#relationship between actual values and predicted value

# %%
sns.lineplot(data=df,x='Actual',y='Predicted')
# Out:
# <Axes: xlabel='Actual', ylabel='Predicted'>

# %%
#random forest regressions accuracy
r2_score(y_test,y_pred)
# Out:
# 0.8871167325120093

# %%
#linear regression -train and predict the data

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
pred=regression.predict(x_test)
r2_score(y_test,pred)
# Out:
# 0.9645570314961525

# %%
d= pd.DataFrame({'Actual': y_test, 'Predicted':pred})
d.head()
# Out:
#       Actual  Predicted
# 10  1.572548   1.571178
# 67  1.652296   1.649889
# 59  1.633172   1.626803
# 33  1.632376   1.631013
# 83  1.695451   1.693912

# %%
#relationship between actual value vs predicted
sns.lineplot(data=d,x=d['Actual'],y=d['Predicted'])
# Out:
# <Axes: xlabel='Actual', ylabel='Predicted'>

# %%
# accuracy score values

# %%
r2_score(y_test,pred)
# Out:
# 0.9645570314961525

# %%
print('Mean Absolute Error:',
      metrics.mean_absolute_error(y_test, pred))
# Out:
# Mean Absolute Error: 0.004991778533335878

# %%
#compare to random forest linear regression has a highest accuracy percentage
